# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Hands-on Lab: Create your Jupyter Notebook

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Final Project

# %% [markdown]
# ## Introduction
# This notebook presents exercises related to Data Science. It includes various tasks that demonstrate basic operations and tools used in data science.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - SQL
# - Java
# - Julia

# %% [markdown]
# ## Data Science Libraries
# - Pandas
# - NumPy
# - Matplotlib
# - Scikit-learn
# - TensorFlow

# %% [markdown]
# ## Data Science Tools
#
# | Tool         | Purpose                     |
# |--------------|-----------------------------|
# | Jupyter      | Interactive coding environment |
# | GitHub       | Version control and collaboration |
# | TensorFlow   | Deep learning framework     |
# | RStudio      | Integrated development environment for R |

# %% [markdown]
# ## Arithmetic Expression Examples
# Here, we will demonstrate basic arithmetic operations such as addition, subtraction, multiplication, and division.

# %% [markdown]
# Copyright ©2024 IBM Corporation. All rights reserved.

# %%
# Multiply and Add
a = 5
b = 3
result_multiply = a * b
result_add = a + b

result_multiply, result_add
# Out:
# (15, 8)

# %%
# Convert minutes to hours
minutes = 120
hours = minutes / 60

hours
# Out:
# 2.0

# %% [markdown]
# ## Objectives
# - To demonstrate basic data science concepts
# - To practice working with data science languages and libraries
# - To use Jupyter for creating and sharing notebooks

# %% [markdown]
# ## Author
# Sharif Perwez
